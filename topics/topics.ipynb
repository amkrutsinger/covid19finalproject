# %% [markdown]
# ## Setup
#
# Run the command below to install the [cord19](https://github.com/dgunning/cord19) library which provides easy processing capabilities for the research paper dataset from the [COVID-19 Open Research Dataset Challenge](https://www.kaggle.com/allen-institute-for-ai/CORD-19-research-challenge). Then download the data directory from the Kaggle challenge (an account is required) into a directory `data` such there exists the directory `data/CORD-19-research-challenge`. However, there is no need to download the data if you are loading the data from a pickle.

# %%
import sys
# !{sys.executable} -m pip install git+https://github.com/dgunning/cord19.git numpy pandas scikit-learn
# Out:
# Collecting git+https://github.com/dgunning/cord19.git
#   Cloning https://github.com/dgunning/cord19.git to /private/var/folders/r9/tg0dy4g52_zf8yd0xqdl3q4h0000gn/T/pip-req-build-dliqhs_s
#   Running command git clone -q https://github.com/dgunning/cord19.git /private/var/folders/r9/tg0dy4g52_zf8yd0xqdl3q4h0000gn/T/pip-req-build-dliqhs_s
# Requirement already satisfied: numpy in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (1.18.1)
# Requirement already satisfied: pandas in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (1.0.3)
# Requirement already satisfied: scikit-learn in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (0.22.1)
# Requirement already satisfied: lxml in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from cord19==0.4.0) (4.5.0)
# Requirement already satisfied: html5lib in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from cord19==0.4.0) (1.0.1)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting simplejson
#   Downloading simplejson-3.17.0-cp37-cp37m-macosx_10_14_x86_64.whl (73 kB)
#      |████████████████████████████████| 73 kB 1.7 MB/s eta 0:00:011
# Requirement already satisfied: scipy==1.4.1 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from cord19==0.4.0) (1.4.1)
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.tar.gz (4.2 kB)
# Requirement already satisfied: nltk in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from cord19==0.4.0) (3.4.5)
# Requirement already satisfied: tqdm>=4.42.0 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from cord19==0.4.0) (4.44.1)
# Collecting pendulum
#   Downloading pendulum-2.1.0-cp37-cp37m-macosx_10_13_x86_64.whl (122 kB)
#      |████████████████████████████████| 122 kB 7.0 MB/s eta 0:00:01
# Requirement already satisfied: pytest in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from cord19==0.4.0) (5.4.1)
# Collecting gensim
#   Downloading gensim-3.8.3-cp37-cp37m-macosx_10_9_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 11.6 MB/s eta 0:00:01
# Collecting pyarrow>=0.16.0
#   Downloading pyarrow-0.17.0-cp37-cp37m-macosx_10_9_intel.whl (42.0 MB)
#      |████████████████████████████████| 42.0 MB 11.5 MB/s eta 0:00:01
# Collecting altair
#   Downloading altair-4.1.0-py3-none-any.whl (727 kB)
#      |████████████████████████████████| 727 kB 3.4 MB/s eta 0:00:01
# Collecting annoy
#   Downloading annoy-1.16.3.tar.gz (644 kB)
#      |████████████████████████████████| 644 kB 15.3 MB/s eta 0:00:01
# Requirement already satisfied: ipywidgets>=7.5.1 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from cord19==0.4.0) (7.5.1)
# Collecting markdown>=3.2.1
#   Downloading Markdown-3.2.1-py2.py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 9.7 MB/s  eta 0:00:01
# Requirement already satisfied: Pygments>=2.6.1 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from cord19==0.4.0) (2.6.1)
# Collecting azure-storage
#   Downloading azure_storage-0.36.0-py2.py3-none-any.whl (190 kB)
#      |████████████████████████████████| 190 kB 17.8 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied: joblib>=0.11 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn) (0.14.1)
# Requirement already satisfied: six>=1.9 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from html5lib->cord19==0.4.0) (1.14.0)
# Requirement already satisfied: webencodings in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from html5lib->cord19==0.4.0) (0.5.1)
# Requirement already satisfied: beautifulsoup4 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from bs4->cord19==0.4.0) (4.8.2)
# Collecting pytzdata>=2018.3
#   Downloading pytzdata-2019.3-py2.py3-none-any.whl (489 kB)
#      |████████████████████████████████| 489 kB 25.1 MB/s eta 0:00:01
# Requirement already satisfied: py>=1.5.0 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from pytest->cord19==0.4.0) (1.8.1)
# Requirement already satisfied: packaging in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from pytest->cord19==0.4.0) (20.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from pytest->cord19==0.4.0) (19.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from pytest->cord19==0.4.0) (8.2.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from pytest->cord19==0.4.0) (0.13.1)
# Requirement already satisfied: wcwidth in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from pytest->cord19==0.4.0) (0.1.9)
# Requirement already satisfied: importlib-metadata>=0.12 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from pytest->cord19==0.4.0) (1.5.0)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-2.0.0.tar.gz (103 kB)
#      |████████████████████████████████| 103 kB 15.8 MB/s eta 0:00:01
# Requirement already satisfied: entrypoints in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from altair->cord19==0.4.0) (0.3)
# Requirement already satisfied: jinja2 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from altair->cord19==0.4.0) (2.11.1)
# Requirement already satisfied: toolz in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from altair->cord19==0.4.0) (0.10.0)
# Requirement already satisfied: jsonschema in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from altair->cord19==0.4.0) (3.2.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.5.1->cord19==0.4.0) (7.13.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.5.1->cord19==0.4.0) (5.1.4)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.5.1->cord19==0.4.0) (4.3.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.5.1->cord19==0.4.0) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipywidgets>=7.5.1->cord19==0.4.0) (5.0.4)
# Requirement already satisfied: setuptools>=36 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from markdown>=3.2.1->cord19==0.4.0) (46.1.3.post20200330)
# Requirement already satisfied: cryptography in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from azure-storage->cord19==0.4.0) (2.8)
# Requirement already satisfied: requests in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from azure-storage->cord19==0.4.0) (2.23.0)
# Collecting azure-common>=1.1.5
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting azure-nspkg>=2.0.0
#   Downloading azure_nspkg-3.0.2-py3-none-any.whl (1.5 kB)
# Requirement already satisfied: soupsieve>=1.2 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from beautifulsoup4->bs4->cord19==0.4.0) (2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from packaging->pytest->cord19==0.4.0) (2.4.6)
# Requirement already satisfied: zipp>=0.5 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest->cord19==0.4.0) (2.2.0)
# Requirement already satisfied: boto in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from smart-open>=1.8.1->gensim->cord19==0.4.0) (2.49.0)
# Collecting boto3
#   Downloading boto3-1.13.3-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 4.0 MB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from jinja2->altair->cord19==0.4.0) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from jsonschema->altair->cord19==0.4.0) (0.16.0)
# Requirement already satisfied: pickleshare in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (3.0.4)
# Requirement already satisfied: decorator in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (4.4.2)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (0.1.0)
# Requirement already satisfied: backcall in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (4.8.0)
# Requirement already satisfied: jedi>=0.10 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (0.15.2)
# Requirement already satisfied: jupyter-client in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->cord19==0.4.0) (6.1.2)
# Requirement already satisfied: tornado>=4.2 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->cord19==0.4.0) (6.0.4)
# Requirement already satisfied: ipython-genutils in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.3.1->ipywidgets>=7.5.1->cord19==0.4.0) (0.2.0)
# Requirement already satisfied: notebook>=4.4.1 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (6.0.3)
# Requirement already satisfied: jupyter-core in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->cord19==0.4.0) (4.6.3)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from cryptography->azure-storage->cord19==0.4.0) (1.14.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from requests->azure-storage->cord19==0.4.0) (1.25.8)
# Requirement already satisfied: idna<3,>=2.5 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from requests->azure-storage->cord19==0.4.0) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from requests->azure-storage->cord19==0.4.0) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from requests->azure-storage->cord19==0.4.0) (3.0.4)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 8.9 MB/s  eta 0:00:01
# Collecting botocore<1.17.0,>=1.16.3
#   Downloading botocore-1.16.3-py2.py3-none-any.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 14.3 MB/s eta 0:00:01
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.9.5-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (0.6.0)
# Requirement already satisfied: parso>=0.5.2 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->cord19==0.4.0) (0.5.2)
# Requirement already satisfied: pyzmq>=13 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.5.1->cord19==0.4.0) (18.1.1)
# Requirement already satisfied: nbconvert in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (0.8.3)
# Requirement already satisfied: Send2Trash in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (1.5.0)
# Requirement already satisfied: prometheus-client in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (0.7.1)
# Requirement already satisfied: pycparser in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography->azure-storage->cord19==0.4.0) (2.20)
# Collecting docutils<0.16,>=0.10
#   Downloading docutils-0.15.2-py3-none-any.whl (547 kB)
#      |████████████████████████████████| 547 kB 11.9 MB/s eta 0:00:01
# Requirement already satisfied: bleach in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (3.1.0)
# Requirement already satisfied: defusedxml in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (0.8.4)
# Requirement already satisfied: testpath in /Users/annakrutsinger/opt/anaconda3/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->cord19==0.4.0) (0.4.4)
# Building wheels for collected packages: cord19, bs4, rank-bm25, annoy, smart-open
#   Building wheel for cord19 (setup.py) ... done
#   Created wheel for cord19: filename=cord19-0.4.0-py3-none-any.whl size=60265304 sha256=9dbea29103e2baf3022a8f8186b8b83779d5e8ff921cade284271700f32ce27c
#   Stored in directory: /private/var/folders/r9/tg0dy4g52_zf8yd0xqdl3q4h0000gn/T/pip-ephem-wheel-cache-whwvieps/wheels/bd/f0/e6/be8f5782d60e3a86ac1f74c92944f94fd3454654a097a3c916
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=73afeb2e87ef23068e5cd78daf34f7279d4dd6a5e2312091f8f4231cea81edbe
#   Stored in directory: /Users/annakrutsinger/Library/Caches/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
#   Building wheel for rank-bm25 (setup.py) ... done
#   Created wheel for rank-bm25: filename=rank_bm25-0.2-py3-none-any.whl size=4161 sha256=e964153ea10287dbf821542491b760e8a3f227f9a221e2edd1142ab0927488a4
#   Stored in directory: /Users/annakrutsinger/Library/Caches/pip/wheels/a7/ae/a2/bc836dd67721b123fe31c3d4dce111ff782f898e7c7fdabc7f
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.16.3-cp37-cp37m-macosx_10_9_x86_64.whl size=67970 sha256=01aec9cd1b6f278cb7fe05dd2edf6e1d67d342531a46eeea8919d273eed97ddf
#   Stored in directory: /Users/annakrutsinger/Library/Caches/pip/wheels/39/36/d4/ee348a7240ca3e8d1fcbf04ebe46d45f2879ccb094a40f5706
#   Building wheel for smart-open (setup.py) ... done
#   Created wheel for smart-open: filename=smart_open-2.0.0-py3-none-any.whl size=101341 sha256=4d323d46584f8537cef603ee36cc7a9d73ca7a02e880cc9612814a2e4e73d41d
#   Stored in directory: /Users/annakrutsinger/Library/Caches/pip/wheels/bb/1c/9c/412ec03f6d5ac7d41f4b965bde3fc0d1bd201da5ba3e2636de
# Successfully built cord19 bs4 rank-bm25 annoy smart-open
# Installing collected packages: bs4, simplejson, rank-bm25, pytzdata, pendulum, docutils, jmespath, botocore, s3transfer, boto3, smart-open, gensim, pyarrow, altair, annoy, markdown, azure-common, azure-nspkg, azure-storage, cord19
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.16
#     Uninstalling docutils-0.16:
#       Successfully uninstalled docutils-0.16
# Successfully installed altair-4.1.0 annoy-1.16.3 azure-common-1.1.25 azure-nspkg-3.0.2 azure-storage-0.36.0 boto3-1.13.3 botocore-1.16.3 bs4-0.0.1 cord19-0.4.0 docutils-0.15.2 gensim-3.8.3 jmespath-0.9.5 markdown-3.2.1 pendulum-2.1.0 pyarrow-0.17.0 pytzdata-2019.3 rank-bm25-0.2 s3transfer-0.3.3 simplejson-3.17.0 smart-open-2.0.0

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/annakrutsinger/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction import text

# %%
from cord import ResearchPapers
try:
    papers = ResearchPapers.from_pickle()
except:
    papers = ResearchPapers.load()
    papers.save()

papers_covid = papers.since_sarscov2()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-064791635c35> in <module>
# ----> 1 from cord import ResearchPapers
#       2 try:
#       3     papers = ResearchPapers.from_pickle()
#       4 except:
#       5     papers = ResearchPapers.load()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cord/__init__.py in <module>
# ----> 1 from .cord19 import ResearchPapers, SearchResults
#       2 from .jsonpaper import JsonCatalog, JsonPaper
#       3 from .core import *
#       4 from .text import *
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cord/cord19.py in <module>
#      18     get_json_paths, get_token_df
#      19 from cord.text import preprocess, shorten, summarize
# ---> 20 from cord.vectors import show_2d_chart, similar_papers
#      21
#      22 _MINIMUM_SEARCH_SCORE = 2
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cord/vectors.py in <module>
#      18 RANDOM_STATE = 42
#      19 NUM_ANNOY_TREES = 30
# ---> 20 SPECTOR_CSV_PATH = Path(find_data_dir()) / config.spector_csv_path
#      21 DOCUMENT_VECTOR_LENGTH = 192
#      22
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cord/core.py in find_data_dir()
#      57         if input_path.exists():
#      58             return str(input_path / CORD_CHALLENGE_PATH)
# ---> 59     assert input_path.exists(), f'Cannot find the input dir should be {input_dir}/{CORD_CHALLENGE_PATH}'
#      60
#      61
#
# AssertionError: Cannot find the input dir should be data/CORD-19-research-challenge

# %% [markdown]
# ## Work

# %%
# lazily store vectorizer and topics in same object
class LDA():
    def fit(self, data, my_stops=[], min_df=10, n_components=8, n_jobs=-1):
        self.vectorizer = CountVectorizer(
            min_df=min_df,
            stop_words=text.ENGLISH_STOP_WORDS.union(my_stops))
        counts = self.vectorizer.fit_transform(data)
        self.topics = LatentDirichletAllocation(
                n_components=n_components,
                random_state=0,
                n_jobs=n_jobs).fit(counts)
        return self
    
    def print_topics(self, n_words=8):
        topic_dists = (self.topics.components_.T / self.topics.components_.sum(axis=1)).T
        for comp in range(len(topic_dists)):
            top_i = np.argsort(topic_dists[comp])[-n_words:][::-1]
            print(f"{[key for key, value in self.vectorizer.vocabulary_.items() if value in top_i]}")

# %%
covid_stops = [
    "coronavirus", "corona", "covid", "sars", "cov", "19",
    "virus", "viruses", "viral", "disease", "diseases", "2019", "2020"
]

# %% [markdown]
# ### Attempt with summaries

# %%
def clean_summary(summary):
    return summary.replace("\n", " ")

def get_summaries(papers):
    return pd.Series([clean_summary(papers[i].summary) for i in range(len(papers))])

# %%
summaries = get_summaries(papers_covid)

# %%
lda_summaries = LDA().fit(summaries,
                          n_components=20, 
                          my_stops=covid_stops)

# %%
lda_summaries.print_topics()

# %% [markdown]
# ### Atempt with titles

# %%
def get_titles(papers):
    return pd.Series([papers[i].title for i in range(len(papers))])

# %%
titles = get_titles(papers_covid)

# %%
lda_titles = LDA().fit(titles,
                       n_components=20,
                       my_stops=covid_stops)

# %%
lda_titles.print_topics()

# %% [markdown]
# ### Attempt with searching before LDA

# %%
papers_relationship = papers_covid.search("variable")

# %%
papers_relationship

# %% [markdown]
# ### Future stuff

# %% [markdown]
# Goal once topics returned by LDA above become useful: use keywords from topics as search terms to find relevant papers for each topic. Searching can be done by `papers.search("term1 term2 [...]")`. Looking more into the papers may be able to reveal what the actual relationship between different variables a given topic may represent. Note the search feature (provided by the `cord19` library), is smart and uses NLP to search by word similarity, not just literal occurences of the search terms.
#
# Also a solution to the current issue of useless topics may be: searching _before_ running LDA. That is, start with a corpus of papers that already investigate relationships.
